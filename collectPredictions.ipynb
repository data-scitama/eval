# %% [markdown]
# # Reference for original source code
# https://github.com/CatalystCode/Custom-Vison-Service/blob/master/FoodClassification/Scripts/evalWebServiceHierarchy.py

# %%
import random, os
import time
import requests
import pandas as pd
import numpy as np
from IPython.display import Image, display
import json

# TODO: CHANGE ME!!
endpoint = "https://southcentralus.api.cognitive.microsoft.com/customvision/v2.0/Prediction/e96d01c2-e320-48c9-b85e-0fa01890e426/image?iterationId=bdb4dfa1-4921-41a8-b8ce-e6ac2e916d98"
key = '4e88879f828247029ed8fbe2fc805da3'

# %% [markdown]
# # Part I
# Test one random image.

# %% [markdown]
# ## 1.1 get random image path and show

# %%
#dir_path = os.getcwd()
dir_path = 'exttestset/008.ข้าวหมูกระเทียมพริกไทย/'

random_filename = random.choice([
    x for x in os.listdir(dir_path)
    if os.path.isfile(os.path.join(dir_path, x)) and os.path.splitext(x)[1]=='.jpg'
])

print(random_filename)
filepath = os.path.join(dir_path, random_filename)
print(filepath)

Image(filename=filepath)

# %% [markdown]
# [How to display a random picture from a folder (Python)](https://stackoverflow.com/questions/26467804/how-to-display-a-random-picture-from-a-folder-python)
#
#
# [How can I display an image from a file in Jupyter Notebook?](https://stackoverflow.com/questions/11854847/how-can-i-display-an-image-from-a-file-in-jupyter-notebook?noredirect=1&lq=1)

# %%
data = open(filepath, 'rb').read()
start_time_req = time.time()
resp = requests.post(endpoint,
                     data=data,
                     headers={'Content-Type': 'application/octet-stream', 'Prediction-Key': key})

# %%
#print(json.dumps(json.loads(resp.content),indent=4, sort_keys=True))
print(json.dumps(resp.json(),indent=4, sort_keys=True))

# %% [markdown]
# [How to prettyprint a JSON file?](https://stackoverflow.com/questions/12943819/how-to-prettyprint-a-json-file)

# %% [markdown]
# # Part II
# Test all images in test set.

# %% [markdown]
# ## 2.1

# %%
MAX_Iterations = 200000


print("Reading input csv with images paths and labels")
filePath = 'ext.csv'
print("file: {0}".format(filePath))
df = pd.read_csv(filePath,header=0)

y_true = []
y_pred = []
y_pred_multi = []

start_time = time.time()
for index, row in df.iterrows():
    if index > MAX_Iterations:
        break
    if index % 10 == 0:
        elapsed_time = time.time() - start_time
        print("processing interation {0}, elapsed time {1}".format(
            index, elapsed_time))
    path = row[0]
    label = row[1]
    resp = None
    try:
        data = open(path, 'rb').read()
        start_time_req = time.time()
        resp = requests.post(endpoint,
                             data=data,
                             headers={'Content-Type': 'application/octet-stream', 'Prediction-Key': key})
        elapsed_time_req = time.time() - start_time
        if index % 10 == 0:
            print("elapsed time  for req # {0} is {1}".format(
                index, elapsed_time_req))
    except Exception as e:
        print("Error opening file or sending request")
        print(e.__doc__)
        print(e.message)
    if resp != None and resp.status_code == requests.codes.ok:
        jsonResponse = resp.json()
        try:
            predictedClass = jsonResponse["predictions"][0]["tagName"]
            predictedProb = jsonResponse["predictions"][0]["probability"]
            y_true.append(label)
            y_pred.append(predictedClass)
            y_pred_multi.append(jsonResponse["predictions"])
        except Exception as e:
            print("Error parsing json response")
            print(e.__doc__)
            print(e.message)
    else:
        print("Got status code {0} for image '{1}' label {2}".format(
            resp.status_code, path, label))
# Out:
# Reading input csv with images paths and labels
# file: ext.csv
# processing interation 0, elapsed time 0.0011909008026123047
# elapsed time  for req # 0 is 4.675339698791504
# processing interation 10, elapsed time 28.650245904922485
# elapsed time  for req # 10 is 31.410717010498047
# processing interation 20, elapsed time 55.55096983909607
# elapsed time  for req # 20 is 60.424556732177734
# processing interation 30, elapsed time 88.11213397979736
# elapsed time  for req # 30 is 90.14153289794922
# processing interation 40, elapsed time 116.88371896743774
# elapsed time  for req # 40 is 119.26529884338379
# processing interation 50, elapsed time 166.72211575508118
# elapsed time  for req # 50 is 169.09213972091675
# processing interation 60, elapsed time 190.20520877838135
# elapsed time  for req # 60 is 196.13085079193115
# processing interation 70, elapsed time 222.7154848575592
# elapsed time  for req # 70 is 226.26195311546326
# processing interation 80, elapsed time 247.8391478061676
# elapsed time  for req # 80 is 252.50254487991333
# processing interation 90, elapsed time 285.51808190345764
# elapsed time  for req # 90 is 289.07474088668823
# processing interation 100, elapsed time 310.2179169654846
# elapsed time  for req # 100 is 315.68355202674866
# processing interation 110, elapsed time 340.81425166130066
# elapsed time  for req # 110 is 342.86879801750183
# processing interation 120, elapsed time 384.93261981010437
# elapsed time  for req # 120 is 387.77154779434204
# processing interation 130, elapsed time 408.8850817680359
# elapsed time  for req # 130 is 410.84426975250244
# processing interation 140, elapsed time 439.07756900787354
# elapsed time  for req # 140 is 443.37998485565186
# processing interation 150, elapsed time 468.06192088127136
# elapsed time  for req # 150 is 470.7127149105072
# processing interation 160, elapsed time 503.4391219615936
# elapsed time  for req # 160 is 505.80121302604675
# processing interation 170, elapsed time 531.6992180347443
# elapsed time  for req # 170 is 534.4079167842865
# processing interation 180, elapsed time 566.5220108032227
# elapsed time  for req # 180 is 571.8335089683533
# processing interation 190, elapsed time 613.7694048881531
# elapsed time  for req # 190 is 616.532928943634
# processing interation 200, elapsed time 660.0572528839111
# elapsed time  for req # 200 is 663.4055078029633
# processing interation 210, elapsed time 706.5523920059204
# elapsed time  for req # 210 is 709.6051647663116
# processing interation 220, elapsed time 739.0062427520752
# elapsed time  for req # 220 is 741.4863708019257
# processing interation 230, elapsed time 772.1663010120392
# elapsed time  for req # 230 is 775.0708470344543
# processing interation 240, elapsed time 804.3344719409943
# elapsed time  for req # 240 is 809.5476999282837
# processing interation 250, elapsed time 837.7730169296265
# elapsed time  for req # 250 is 840.9518437385559
# processing interation 260, elapsed time 872.4354009628296
# elapsed time  for req # 260 is 875.3179609775543
# processing interation 270, elapsed time 931.8885898590088
# elapsed time  for req # 270 is 935.0524749755859
# processing interation 280, elapsed time 978.7288749217987
# elapsed time  for req # 280 is 982.1329228878021
# processing interation 290, elapsed time 1066.5906648635864
# elapsed time  for req # 290 is 1070.5096080303192
# processing interation 300, elapsed time 1159.2848126888275
# elapsed time  for req # 300 is 1163.265832901001
# processing interation 310, elapsed time 1194.1720418930054
# elapsed time  for req # 310 is 1206.1533629894257
# processing interation 320, elapsed time 1232.5283620357513
# elapsed time  for req # 320 is 1234.8467919826508
# processing interation 330, elapsed time 1261.4850029945374
# elapsed time  for req # 330 is 1264.220638036728
# processing interation 340, elapsed time 1296.4704520702362
# elapsed time  for req # 340 is 1308.756763935089
# processing interation 350, elapsed time 1343.7992436885834
# elapsed time  for req # 350 is 1350.9868140220642
# processing interation 360, elapsed time 1401.5524690151215
# elapsed time  for req # 360 is 1405.2529838085175
# processing interation 370, elapsed time 1436.590616941452
# elapsed time  for req # 370 is 1446.7607288360596
# processing interation 380, elapsed time 1487.1354780197144
# elapsed time  for req # 380 is 1489.645046710968
# processing interation 390, elapsed time 1533.4201319217682
# elapsed time  for req # 390 is 1538.569354057312
# processing interation 400, elapsed time 1567.2168798446655
# elapsed time  for req # 400 is 1570.3372769355774
# processing interation 410, elapsed time 1606.2305710315704
# elapsed time  for req # 410 is 1609.1876480579376
# processing interation 420, elapsed time 1634.4432179927826
# elapsed time  for req # 420 is 1637.5512599945068
# processing interation 430, elapsed time 1664.2550868988037
# elapsed time  for req # 430 is 1668.0455598831177
# processing interation 440, elapsed time 1704.4522047042847
# elapsed time  for req # 440 is 1707.3979909420013
# processing interation 450, elapsed time 1768.367330789566
# elapsed time  for req # 450 is 1771.302358865738
# processing interation 460, elapsed time 1809.4980719089508
# elapsed time  for req # 460 is 1814.530503988266
# processing interation 470, elapsed time 1858.1007158756256
# elapsed time  for req # 470 is 1867.555000782013
# processing interation 480, elapsed time 1907.5594477653503
# elapsed time  for req # 480 is 1909.7949330806732
# processing interation 490, elapsed time 1936.4704070091248
# elapsed time  for req # 490 is 1939.2000210285187
# processing interation 500, elapsed time 2044.7799859046936
# elapsed time  for req # 500 is 2048.043862104416
# processing interation 510, elapsed time 2122.2246417999268
# elapsed time  for req # 510 is 2125.1952619552612
# processing interation 520, elapsed time 2160.0137009620667
# elapsed time  for req # 520 is 2163.389382839203
# processing interation 530, elapsed time 2187.348757982254
# elapsed time  for req # 530 is 2191.288139820099
# processing interation 540, elapsed time 2247.8697617053986
# elapsed time  for req # 540 is 2255.8517229557037
# processing interation 550, elapsed time 2365.526210784912
# elapsed time  for req # 550 is 2377.070049762726
# processing interation 560, elapsed time 2406.517639875412
# elapsed time  for req # 560 is 2409.356402873993
# processing interation 570, elapsed time 2467.048579931259
# elapsed time  for req # 570 is 2477.7598416805267
# processing interation 580, elapsed time 2512.427354812622
# elapsed time  for req # 580 is 2517.2041709423065
# processing interation 590, elapsed time 2550.278520822525
# elapsed time  for req # 590 is 2552.89994597435
# processing interation 600, elapsed time 2600.7027547359467
# elapsed time  for req # 600 is 2603.2729947566986
# processing interation 610, elapsed time 2640.990025997162
# elapsed time  for req # 610 is 2643.850353002548
# processing interation 620, elapsed time 2671.873741865158
# elapsed time  for req # 620 is 2674.5288479328156
# processing interation 630, elapsed time 2704.4733629226685
# elapsed time  for req # 630 is 2707.160805940628
# processing interation 640, elapsed time 2736.5055980682373
# elapsed time  for req # 640 is 2739.28946685791
# processing interation 650, elapsed time 2775.8466517925262
# elapsed time  for req # 650 is 2779.4564497470856
# processing interation 660, elapsed time 2815.5127918720245
# elapsed time  for req # 660 is 2818.3423759937286
# processing interation 670, elapsed time 2846.2673738002777
# elapsed time  for req # 670 is 2856.065705060959
# processing interation 680, elapsed time 2889.616715669632
# elapsed time  for req # 680 is 2892.263258934021
# processing interation 690, elapsed time 2932.92587184906
# elapsed time  for req # 690 is 2935.9039669036865
# processing interation 700, elapsed time 2966.2312557697296
# elapsed time  for req # 700 is 2969.5847177505493
# processing interation 710, elapsed time 3002.251766681671
# elapsed time  for req # 710 is 3004.9015488624573
# processing interation 720, elapsed time 3032.86497092247
# elapsed time  for req # 720 is 3038.429795742035
# processing interation 730, elapsed time 3068.21559882164
# elapsed time  for req # 730 is 3070.629153728485
# processing interation 740, elapsed time 3096.4798748493195
# elapsed time  for req # 740 is 3098.722469806671
# processing interation 750, elapsed time 3132.3380596637726
# elapsed time  for req # 750 is 3135.729991912842
# processing interation 760, elapsed time 3179.0003769397736
# elapsed time  for req # 760 is 3187.4848368167877
# processing interation 770, elapsed time 3244.4651398658752
# elapsed time  for req # 770 is 3249.688934803009
# processing interation 780, elapsed time 3277.930499792099
# elapsed time  for req # 780 is 3280.498169898987
# processing interation 790, elapsed time 3308.6193158626556
# elapsed time  for req # 790 is 3311.715418815613
# processing interation 800, elapsed time 3344.687780857086
# elapsed time  for req # 800 is 3348.0333938598633
# processing interation 810, elapsed time 3379.612025976181
# elapsed time  for req # 810 is 3382.1339910030365
# processing interation 820, elapsed time 3413.2156689167023
# elapsed time  for req # 820 is 3415.7519178390503
# processing interation 830, elapsed time 3444.254946708679
# elapsed time  for req # 830 is 3447.2568860054016
# processing interation 840, elapsed time 3474.3341619968414
# elapsed time  for req # 840 is 3478.22465801239
# processing interation 850, elapsed time 3509.8549859523773
# elapsed time  for req # 850 is 3513.1634109020233
# processing interation 860, elapsed time 3557.9125769138336
# elapsed time  for req # 860 is 3561.542797803879
# processing interation 870, elapsed time 3587.8428468704224
# elapsed time  for req # 870 is 3591.0553119182587
# processing interation 880, elapsed time 3660.799524784088
# elapsed time  for req # 880 is 3667.282697916031
# processing interation 890, elapsed time 3705.6290860176086
# elapsed time  for req # 890 is 3708.6210289001465
# processing interation 900, elapsed time 3741.279242992401
# elapsed time  for req # 900 is 3744.2358169555664
# processing interation 910, elapsed time 3782.9449338912964
# elapsed time  for req # 910 is 3787.3039078712463
# processing interation 920, elapsed time 3836.1904530525208
# elapsed time  for req # 920 is 3839.0887928009033
# processing interation 930, elapsed time 3930.4151639938354
# elapsed time  for req # 930 is 3933.919222831726
# processing interation 940, elapsed time 3988.5020608901978
# elapsed time  for req # 940 is 3991.5303428173065
# processing interation 950, elapsed time 4026.915449857712
# elapsed time  for req # 950 is 4029.7416138648987
# processing interation 960, elapsed time 4095.0763080120087
# elapsed time  for req # 960 is 4099.335630893707
# processing interation 970, elapsed time 4135.928646802902
# elapsed time  for req # 970 is 4139.921663045883
# processing interation 980, elapsed time 4170.1666560173035
# elapsed time  for req # 980 is 4181.797233819962
# processing interation 990, elapsed time 4213.227318048477
# elapsed time  for req # 990 is 4216.595262050629
# processing interation 1000, elapsed time 4241.547518968582
# elapsed time  for req # 1000 is 4263.830185890198
# processing interation 1010, elapsed time 4301.282727956772
# elapsed time  for req # 1010 is 4304.281054019928
# processing interation 1020, elapsed time 4350.359190702438
# elapsed time  for req # 1020 is 4353.161299943924
# processing interation 1030, elapsed time 4381.181457996368
# elapsed time  for req # 1030 is 4384.071350097656
# processing interation 1040, elapsed time 4416.165856838226
# elapsed time  for req # 1040 is 4420.7068428993225
# processing interation 1050, elapsed time 4450.711809873581
# elapsed time  for req # 1050 is 4453.440711975098
# processing interation 1060, elapsed time 4481.330420017242
# elapsed time  for req # 1060 is 4484.156483888626
# processing interation 1070, elapsed time 4516.410051822662
# elapsed time  for req # 1070 is 4522.162979841232
# processing interation 1080, elapsed time 4561.737417936325
# elapsed time  for req # 1080 is 4564.3307428359985
# processing interation 1090, elapsed time 4593.490984916687
# elapsed time  for req # 1090 is 4595.930470943451
# processing interation 1100, elapsed time 4640.52277302742
# elapsed time  for req # 1100 is 4662.091842889786
# processing interation 1110, elapsed time 4699.444271802902
# elapsed time  for req # 1110 is 4703.636006832123
# processing interation 1120, elapsed time 4745.74294090271
# elapsed time  for req # 1120 is 4748.246678829193
# processing interation 1130, elapsed time 4800.52757692337
# elapsed time  for req # 1130 is 4803.788382053375
# processing interation 1140, elapsed time 4834.842892885208
# elapsed time  for req # 1140 is 4837.650134801865
# processing interation 1150, elapsed time 4865.223315954208
# elapsed time  for req # 1150 is 4870.933271884918
# processing interation 1160, elapsed time 4900.24175286293
# elapsed time  for req # 1160 is 4902.680183887482
# processing interation 1170, elapsed time 4931.486251831055
# elapsed time  for req # 1170 is 4933.9440948963165
# processing interation 1180, elapsed time 4962.197901725769
# elapsed time  for req # 1180 is 4965.478873968124
# processing interation 1190, elapsed time 4995.328761816025
# elapsed time  for req # 1190 is 4998.555564880371
# processing interation 1200, elapsed time 5030.836934804916
# elapsed time  for req # 1200 is 5034.246782064438
# processing interation 1210, elapsed time 5076.564278841019
# elapsed time  for req # 1210 is 5078.918848991394
# processing interation 1220, elapsed time 5122.029994010925
# elapsed time  for req # 1220 is 5124.4244248867035
# processing interation 1230, elapsed time 5161.2783670425415
# elapsed time  for req # 1230 is 5168.133686065674
# processing interation 1240, elapsed time 5213.395212888718
# elapsed time  for req # 1240 is 5217.284174919128
# processing interation 1250, elapsed time 5257.437376976013
# elapsed time  for req # 1250 is 5261.22661781311
# processing interation 1260, elapsed time 5308.336661100388
# elapsed time  for req # 1260 is 5319.99424290657
# processing interation 1270, elapsed time 5394.7408657073975
# elapsed time  for req # 1270 is 5398.529980897903
# processing interation 1280, elapsed time 5427.367434024811
# elapsed time  for req # 1280 is 5430.772655963898
# processing interation 1290, elapsed time 5466.422708034515
# elapsed time  for req # 1290 is 5469.395591020584
# processing interation 1300, elapsed time 5512.087567806244
# elapsed time  for req # 1300 is 5515.220391988754
# processing interation 1310, elapsed time 5557.553932905197
# elapsed time  for req # 1310 is 5561.190625905991
# processing interation 1320, elapsed time 5599.56685090065
# elapsed time  for req # 1320 is 5602.4562458992
# processing interation 1330, elapsed time 5642.549105882645
# elapsed time  for req # 1330 is 5645.6618139743805
# processing interation 1340, elapsed time 5735.525216817856
# elapsed time  for req # 1340 is 5737.974026918411
# processing interation 1350, elapsed time 5779.539995908737
# elapsed time  for req # 1350 is 5829.5399470329285
# processing interation 1360, elapsed time 5866.234965085983
# elapsed time  for req # 1360 is 5870.806078910828
# processing interation 1370, elapsed time 5914.235917806625
# elapsed time  for req # 1370 is 5917.083889961243
# processing interation 1380, elapsed time 5947.910093784332
# elapsed time  for req # 1380 is 5950.703493833542
# processing interation 1390, elapsed time 5997.02810883522
# elapsed time  for req # 1390 is 5999.72970700264
# processing interation 1400, elapsed time 6032.163717985153
# elapsed time  for req # 1400 is 6035.872777938843
# processing interation 1410, elapsed time 6077.03727889061
# elapsed time  for req # 1410 is 6079.695606708527

# %%
image_path = list(df.loc[:,'image'])

import pickle
with open("iter8_predictions.pickle","wb") as f:
    pickle.dump((image_path, y_true, y_pred, y_pred_multi), f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-90a588c47fbe> in <module>()
# ----> 1 image_path = list(df.loc[:,'image'])
#       2
#       3 import pickle
#       4 with open("iter8_predictions.pickle","wb") as f:
#       5     pickle.dump((image_path, y_true, y_pred, y_pred_multi), f)
#
# NameError: name 'df' is not defined
